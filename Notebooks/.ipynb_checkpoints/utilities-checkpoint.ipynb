# %%
# =====
# File parsers
# =====
import os
from pathlib import Path
import re
import pandas as pd

def get_pdr():
    """Gets the 'Parkinson's Disease Repository' parent folder"""
    
    # Get path
    path = Path(os.getcwd())
    
    cwd = ''
    
    # Get parent folder
    while ('Parkinson-Disease-Repository' in cwd) == False:
        path = path.parent
        
        # Get current directory
        cwd = str(path).split('\\')[-1]
        
    return str(path)
    
def get_all_files(parent):
    """Collects all files located within the folders in file_list
    Warning: Might not do well with folders containing links that may lead to an endless loop

    Parameters: 
    =====
    parent: str
        Parent directory for which to collect all files
        
    Returns
    =====
    all_files: ()[]
        List of files, exist as tuple of '(file name, absolute path)'
    """
    all_files = []
    
    for root, dirs, files in os.walk(parent):
        if files:
            for file in files:
                all_files.append((file, root + '\\' + file))
    
    return all_files

def get_csv_files(all_files):
    """Gets the list of csv files from all_files
    
    Parameters
    =====
    all_files: ()[]
        List of files existing as tuple as per get_all_files()
        
    Returns
    =====
    new_files: ()[]
        List of files existing as tuple as per get_all_files(), but CSV only
    """
    # Rather than getting all those with .csv, we eliminate those with the following
    ignore_list = [
        'ipynb',
        'png'
    ]
    ignore_regex = '|'.join(map(lambda x : '.' + x, ignore_list))
    ignore_regex = '(' + ignore_regex + ')' + '$'
    
    new_files = []
    
    for file, path in all_files:
        if not re.search(ignore_regex, file):
            new_files.append((file, path))

    return new_files

def extract_json_from_name(file):
    """Extracts a JSON from the given file name
    
    Paramters
    =====
    file: (), tuple
        As per get_all_files()
    
    Returns
    =====
    json: dictionary
        {
            name: str # the name of the file
        }
    """
    json = {}
    
    return json

def structure_csv_files(files, json = False):
    """
    Structures the CSV files into an easy-to-read dataframe format
    They can also be structured into a JSON format
    
    Parameters
    =====
    files: ()[]
        As per get_all_files() structure, list of files
    json: boolean
        Whether the information should be returned as JSON
    """
    df = pd.DataFrame(files, columns = ["name", "path"])
    
    
    # Get time from name
    df['time'] = df['name'].apply(lambda x : re.search('\d\d\d\d-\d\d-\d\dT[\d]+.\d\d\.\d\d\.\d\d\d( [ap]m)?', x).group())
#     # Fix 'PM' or 'AM' in time
#     # Delete all 'AM'
#     df['time'] = df['time'].apply(lambda x : re.sub('_am', '', x))
#     # Increment the time in 'PM'
#     df['time'] = df['time'].apply(lambda x : x)
# #     df['time'].apply(lambda x : print('am' in x))
    
    
    
    df['mishmash'] = df['name'].apply(lambda x : x.split('_'))
    df['test'] = df['mishmash'].apply(lambda x : x[-1])
    df = df.drop(columns = ['mishmash'])
    
    df['name'].apply(lambda x : print(x))
    
    
#     check_for = "time"
#     df['check'] = df[check_for].apply(lambda x : x is None)
#     print("Check for '" + check_for + "' == None is " + str(df['check'].sum() > 0).lower() + ".")
    
    return df

directory = get_pdr()
directory = get_all_files(directory + r'\Data (Archived)')
directory = get_csv_files(directory)
structure_csv_files(directory)
# Out:
# MetaWear_2019-10-23T12.31.18.992 pm_C5013CAC38C1_Accelerometer.csv
# MetaWear_2019-10-23T12.31.18.992 pm_C5013CAC38C1_Gyroscope.csv
# S3_2019-10-23T12.31.18.992 pm_D4B85CC9CCD2_Accelerometer.csv
# S3_2019-10-23T12.31.18.992 pm_D4B85CC9CCD2_Gyroscope.csv
# MetaWear_2019-10-21T2.50.03.179 pm_C5013CAC38C1_Accelerometer.csv
# MetaWear_2019-10-21T2.50.03.179 pm_C5013CAC38C1_Gyroscope.csv
# MetaWear_2019-10-21T3.02.35.260 pm_C5013CAC38C1_Accelerometer.csv
# MetaWear_2019-10-21T3.02.35.260 pm_C5013CAC38C1_Gyroscope.csv
# S4_2019-10-23T12.00.07.369 pm_EB54418CDA46_Accelerometer.csv
# S4_2019-10-23T12.00.07.369 pm_EB54418CDA46_Gyroscope.csv
# tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB54418CDA46_Accelerometer_1.4.4-checkpoint.csv
# tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB54418CDA46_Gyroscope_1.4.4-checkpoint.csv
# tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB54418CDA46_Accelerometer_1.4.4.csv
# tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB54418CDA46_Gyroscope_1.4.4.csv
# tap lvl1 try2_S4_2019-10-25T13.48.31.829_EB54418CDA46_Accelerometer_1.4.4.csv
# tap lvl1 try2_S4_2019-10-25T13.48.31.829_EB54418CDA46_Gyroscope_1.4.4.csv
# tap lvl1 try3_S4_2019-10-25T13.50.11.262_EB54418CDA46_Accelerometer_1.4.4.csv
# tap lvl1 try3_S4_2019-10-25T13.50.11.262_EB54418CDA46_Gyroscope_1.4.4.csv
# tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB54418CDA46_Accelerometer_1.4.4.csv
# tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB54418CDA46_Gyroscope_1.4.4.csv
# tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB54418CDA46_Gyroscope_1.4.4-checkpoint.csv
# pro-sup-lvl1-try1_S4_2019-11-01T20.31.16.187_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl1-try1_S4_2019-11-01T20.31.16.187_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl1-try2_S4_2019-11-01T20.33.42.952_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl1-try2_S4_2019-11-01T20.33.42.952_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl1-try3_S4_2019-11-01T20.44.29.452_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl1-try3_S4_2019-11-01T20.44.29.452_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl3-try1_S4_2019-11-01T20.47.24.116_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl3-try1_S4_2019-11-01T20.47.24.116_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl3-try2_S4_2019-11-01T20.49.46.609_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl3-try2_S4_2019-11-01T20.49.46.609_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl3-try3_S4_2019-11-01T20.51.32.097_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl3-try3_S4_2019-11-01T20.51.32.097_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl5-try1_S4_2019-11-01T20.53.35.588_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl5-try1_S4_2019-11-01T20.53.35.588_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl5-try2_S4_2019-11-01T20.57.44.638_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl5-try2_S4_2019-11-01T20.57.44.638_EB54418CDA46_Gyroscope_1.4.5.csv
# pro-sup-lvl5-try3_S4_2019-11-01T20.59.20.449_EB54418CDA46_Accelerometer_1.4.5.csv
# pro-sup-lvl5-try3_S4_2019-11-01T20.59.20.449_EB54418CDA46_Gyroscope_1.4.5.csv
# dataA0_S4_2019-11-01T21.02.16.129_EB54418CDA46_Accelerometer_1.4.5.csv
# dataA0_S4_2019-11-01T21.02.16.129_EB54418CDA46_Gyroscope_1.4.5.csv
# dataA1_S4_2019-11-01T21.03.59.920_EB54418CDA46_Accelerometer_1.4.5.csv
# dataA1_S4_2019-11-01T21.03.59.920_EB54418CDA46_Gyroscope_1.4.5.csv
# dataA_S4_2019-11-01T20.14.25.824_EB54418CDA46_Accelerometer_1.4.5.csv
# dataA_S4_2019-11-01T20.14.25.824_EB54418CDA46_Gyroscope_1.4.5.csv
# dataB0_S4_2019-11-01T21.07.03.086_EB54418CDA46_Accelerometer_1.4.5.csv
# dataB0_S4_2019-11-01T21.07.03.086_EB54418CDA46_Gyroscope_1.4.5.csv
# dataB1_S4_2019-11-01T21.08.51.975_EB54418CDA46_Accelerometer_1.4.5.csv
# dataB1_S4_2019-11-01T21.08.51.975_EB54418CDA46_Gyroscope_1.4.5.csv
# dataB_S4_2019-11-01T20.24.44.448_EB54418CDA46_Accelerometer_1.4.5.csv
# dataB_S4_2019-11-01T20.24.44.448_EB54418CDA46_Gyroscope_1.4.5.csv
# dataC0_S4_2019-11-01T21.10.20.004_EB54418CDA46_Accelerometer_1.4.5.csv
# dataC0_S4_2019-11-01T21.10.20.004_EB54418CDA46_Gyroscope_1.4.5.csv
# dataC1_S4_2019-11-01T21.12.58.750_EB54418CDA46_Accelerometer_1.4.5.csv
# dataC1_S4_2019-11-01T21.12.58.750_EB54418CDA46_Gyroscope_1.4.5.csv
# dataC_S4_2019-11-01T20.25.12.564_EB54418CDA46_Accelerometer_1.4.5.csv
# dataC_S4_2019-11-01T20.25.12.564_EB54418CDA46_Gyroscope_1.4.5.csv
# tremor-lvl1-try1_S2_2019-11-01T21.30.03.359_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl1-try1_S2_2019-11-01T21.30.03.359_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl1-try2_S2_2019-11-01T21.31.43.269_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl1-try2_S2_2019-11-01T21.31.43.269_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl1-try3_S2_2019-11-01T21.33.43.142_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl1-try3_S2_2019-11-01T21.33.43.142_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl3-8g-1000deg_S2_2019-11-01T21.48.45.175_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl3-8g-1000deg_S2_2019-11-01T21.48.45.175_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl3-try1_S2_2019-11-01T21.36.28.628_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl3-try1_S2_2019-11-01T21.36.28.628_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl3-try2_S2_2019-11-01T21.38.01.379_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl3-try2_S2_2019-11-01T21.38.01.379_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl3-try3_S2_2019-11-01T21.39.53.686_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl3-try3_S2_2019-11-01T21.39.53.686_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl5-8g-1000deg_S2_2019-11-01T21.46.50.774_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl5-8g-1000deg_S2_2019-11-01T21.46.50.774_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl5-try1_S2_2019-11-01T21.42.05.868_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl5-try1_S2_2019-11-01T21.42.05.868_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl5-try2_S2_2019-11-01T21.43.48.391_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl5-try2_S2_2019-11-01T21.43.48.391_C49948A1895C_Gyroscope_1.4.5.csv
# tremor-lvl5-try3_S2_2019-11-01T21.45.17.697_C49948A1895C_Accelerometer_1.4.5.csv
# tremor-lvl5-try3_S2_2019-11-01T21.45.17.697_C49948A1895C_Gyroscope_1.4.5.csv
# experiment1-x-or-y_S3_2019-11-06T01.27.12.657_D4B85CC9CCD2_Accelerometer_1.4.5
# experiment1-x-or-y_S3_2019-11-06T01.27.12.657_D4B85CC9CCD2_Gyroscope_1.4.5
# Simple-motion-trialonly_S3_2019-11-04T15.40.14.588_D4B85CC9CCD2_Accelerometer_1.4.5.csv
# Simple-motion-trialonly_S3_2019-11-04T15.40.14.588_D4B85CC9CCD2_Gyroscope_1.4.5.csv
# Trial_S3_2019-11-03T20.04.55.925_D4B85CC9CCD2_Accelerometer_50.000Hz_1.4.5.csv
# Trial_S3_2019-11-03T20.04.55.925_D4B85CC9CCD2_Gyroscope_50.000Hz_1.4.5.csv
# z-axis-trial_S3_2019-11-04T16.04.52.598_D4B85CC9CCD2_Accelerometer_1.4.5
# z-axis-trial_S3_2019-11-04T16.04.52.598_D4B85CC9CCD2_Gyroscope_1.4.5
#                                                  name  \
# 0   MetaWear_2019-10-23T12.31.18.992 pm_C5013CAC38...
# 1   MetaWear_2019-10-23T12.31.18.992 pm_C5013CAC38...
# 2   S3_2019-10-23T12.31.18.992 pm_D4B85CC9CCD2_Acc...
# 3   S3_2019-10-23T12.31.18.992 pm_D4B85CC9CCD2_Gyr...
# 4   MetaWear_2019-10-21T2.50.03.179 pm_C5013CAC38C...
# 5   MetaWear_2019-10-21T2.50.03.179 pm_C5013CAC38C...
# 6   MetaWear_2019-10-21T3.02.35.260 pm_C5013CAC38C...
# 7   MetaWear_2019-10-21T3.02.35.260 pm_C5013CAC38C...
# 8   S4_2019-10-23T12.00.07.369 pm_EB54418CDA46_Acc...
# 9   S4_2019-10-23T12.00.07.369 pm_EB54418CDA46_Gyr...
# 10  tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB544...
# 11  tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB544...
# 12  tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB544...
# 13  tap lvl1 try1_S4_2019-10-25T13.46.40.964_EB544...
# 14  tap lvl1 try2_S4_2019-10-25T13.48.31.829_EB544...
# 15  tap lvl1 try2_S4_2019-10-25T13.48.31.829_EB544...
# 16  tap lvl1 try3_S4_2019-10-25T13.50.11.262_EB544...
# 17  tap lvl1 try3_S4_2019-10-25T13.50.11.262_EB544...
# 18  tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB544...
# 19  tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB544...
# 20  tap lvl2 try1_S4_2019-10-25T13.55.17.684_EB544...
# 21  pro-sup-lvl1-try1_S4_2019-11-01T20.31.16.187_E...
# 22  pro-sup-lvl1-try1_S4_2019-11-01T20.31.16.187_E...
# 23  pro-sup-lvl1-try2_S4_2019-11-01T20.33.42.952_E...
# 24  pro-sup-lvl1-try2_S4_2019-11-01T20.33.42.952_E...
# 25  pro-sup-lvl1-try3_S4_2019-11-01T20.44.29.452_E...
# 26  pro-sup-lvl1-try3_S4_2019-11-01T20.44.29.452_E...
# 27  pro-sup-lvl3-try1_S4_2019-11-01T20.47.24.116_E...
# 28  pro-sup-lvl3-try1_S4_2019-11-01T20.47.24.116_E...
# 29  pro-sup-lvl3-try2_S4_2019-11-01T20.49.46.609_E...
# ..                                                ...
# 57  tremor-lvl1-try1_S2_2019-11-01T21.30.03.359_C4...
# 58  tremor-lvl1-try1_S2_2019-11-01T21.30.03.359_C4...
# 59  tremor-lvl1-try2_S2_2019-11-01T21.31.43.269_C4...
# 60  tremor-lvl1-try2_S2_2019-11-01T21.31.43.269_C4...
# 61  tremor-lvl1-try3_S2_2019-11-01T21.33.43.142_C4...
# 62  tremor-lvl1-try3_S2_2019-11-01T21.33.43.142_C4...
# 63  tremor-lvl3-8g-1000deg_S2_2019-11-01T21.48.45....
# 64  tremor-lvl3-8g-1000deg_S2_2019-11-01T21.48.45....
# 65  tremor-lvl3-try1_S2_2019-11-01T21.36.28.628_C4...
# 66  tremor-lvl3-try1_S2_2019-11-01T21.36.28.628_C4...
# 67  tremor-lvl3-try2_S2_2019-11-01T21.38.01.379_C4...
# 68  tremor-lvl3-try2_S2_2019-11-01T21.38.01.379_C4...
# 69  tremor-lvl3-try3_S2_2019-11-01T21.39.53.686_C4...
# 70  tremor-lvl3-try3_S2_2019-11-01T21.39.53.686_C4...
# 71  tremor-lvl5-8g-1000deg_S2_2019-11-01T21.46.50....
# 72  tremor-lvl5-8g-1000deg_S2_2019-11-01T21.46.50....
# 73  tremor-lvl5-try1_S2_2019-11-01T21.42.05.868_C4...
# 74  tremor-lvl5-try1_S2_2019-11-01T21.42.05.868_C4...
# 75  tremor-lvl5-try2_S2_2019-11-01T21.43.48.391_C4...
# 76  tremor-lvl5-try2_S2_2019-11-01T21.43.48.391_C4...
# 77  tremor-lvl5-try3_S2_2019-11-01T21.45.17.697_C4...
# 78  tremor-lvl5-try3_S2_2019-11-01T21.45.17.697_C4...
# 79  experiment1-x-or-y_S3_2019-11-06T01.27.12.657_...
# 80  experiment1-x-or-y_S3_2019-11-06T01.27.12.657_...
# 81  Simple-motion-trialonly_S3_2019-11-04T15.40.14...
# 82  Simple-motion-trialonly_S3_2019-11-04T15.40.14...
# 83  Trial_S3_2019-11-03T20.04.55.925_D4B85CC9CCD2_...
# 84  Trial_S3_2019-11-03T20.04.55.925_D4B85CC9CCD2_...
# 85  z-axis-trial_S3_2019-11-04T16.04.52.598_D4B85C...
# 86  z-axis-trial_S3_2019-11-04T16.04.52.598_D4B85C...
#
#                                                  path  \
# 0   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 1   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 2   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 3   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 4   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 5   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 6   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 7   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 8   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 9   C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 10  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 11  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 12  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 13  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 14  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 15  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 16  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 17  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 18  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 19  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 20  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 21  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 22  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 23  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 24  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 25  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 26  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 27  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 28  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 29  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# ..                                                ...
# 57  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 58  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 59  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 60  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 61  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 62  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 63  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 64  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 65  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 66  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 67  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 68  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 69  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 70  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 71  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 72  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 73  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 74  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 75  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 76  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 77  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 78  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 79  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 80  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 81  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 82  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 83  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 84  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 85  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
# 86  C:\Users\liong\Jupyter Notebook\191020_Fourth ...
#
#                           time                  test
# 0   2019-10-23T12.31.18.992 pm     Accelerometer.csv
# 1   2019-10-23T12.31.18.992 pm         Gyroscope.csv
# 2   2019-10-23T12.31.18.992 pm     Accelerometer.csv
# 3   2019-10-23T12.31.18.992 pm         Gyroscope.csv
# 4    2019-10-21T2.50.03.179 pm     Accelerometer.csv
# 5    2019-10-21T2.50.03.179 pm         Gyroscope.csv
# 6    2019-10-21T3.02.35.260 pm     Accelerometer.csv
# 7    2019-10-21T3.02.35.260 pm         Gyroscope.csv
# 8   2019-10-23T12.00.07.369 pm     Accelerometer.csv
# 9   2019-10-23T12.00.07.369 pm         Gyroscope.csv
# 10     2019-10-25T13.46.40.964  1.4.4-checkpoint.csv
# 11     2019-10-25T13.46.40.964  1.4.4-checkpoint.csv
# 12     2019-10-25T13.46.40.964             1.4.4.csv
# 13     2019-10-25T13.46.40.964             1.4.4.csv
# 14     2019-10-25T13.48.31.829             1.4.4.csv
# 15     2019-10-25T13.48.31.829             1.4.4.csv
# 16     2019-10-25T13.50.11.262             1.4.4.csv
# 17     2019-10-25T13.50.11.262             1.4.4.csv
# 18     2019-10-25T13.55.17.684             1.4.4.csv
# 19     2019-10-25T13.55.17.684             1.4.4.csv
# 20     2019-10-25T13.55.17.684  1.4.4-checkpoint.csv
# 21     2019-11-01T20.31.16.187             1.4.5.csv
# 22     2019-11-01T20.31.16.187             1.4.5.csv
# 23     2019-11-01T20.33.42.952             1.4.5.csv
# 24     2019-11-01T20.33.42.952             1.4.5.csv
# 25     2019-11-01T20.44.29.452             1.4.5.csv
# 26     2019-11-01T20.44.29.452             1.4.5.csv
# 27     2019-11-01T20.47.24.116             1.4.5.csv
# 28     2019-11-01T20.47.24.116             1.4.5.csv
# 29     2019-11-01T20.49.46.609             1.4.5.csv
# ..                         ...                   ...
# 57     2019-11-01T21.30.03.359             1.4.5.csv
# 58     2019-11-01T21.30.03.359             1.4.5.csv
# 59     2019-11-01T21.31.43.269             1.4.5.csv
# 60     2019-11-01T21.31.43.269             1.4.5.csv
# 61     2019-11-01T21.33.43.142             1.4.5.csv
# 62     2019-11-01T21.33.43.142             1.4.5.csv
# 63     2019-11-01T21.48.45.175             1.4.5.csv
# 64     2019-11-01T21.48.45.175             1.4.5.csv
# 65     2019-11-01T21.36.28.628             1.4.5.csv
# 66     2019-11-01T21.36.28.628             1.4.5.csv
# 67     2019-11-01T21.38.01.379             1.4.5.csv
# 68     2019-11-01T21.38.01.379             1.4.5.csv
# 69     2019-11-01T21.39.53.686             1.4.5.csv
# 70     2019-11-01T21.39.53.686             1.4.5.csv
# 71     2019-11-01T21.46.50.774             1.4.5.csv
# 72     2019-11-01T21.46.50.774             1.4.5.csv
# 73     2019-11-01T21.42.05.868             1.4.5.csv
# 74     2019-11-01T21.42.05.868             1.4.5.csv
# 75     2019-11-01T21.43.48.391             1.4.5.csv
# 76     2019-11-01T21.43.48.391             1.4.5.csv
# 77     2019-11-01T21.45.17.697             1.4.5.csv
# 78     2019-11-01T21.45.17.697             1.4.5.csv
# 79     2019-11-06T01.27.12.657                 1.4.5
# 80     2019-11-06T01.27.12.657                 1.4.5
# 81     2019-11-04T15.40.14.588             1.4.5.csv
# 82     2019-11-04T15.40.14.588             1.4.5.csv
# 83     2019-11-03T20.04.55.925             1.4.5.csv
# 84     2019-11-03T20.04.55.925             1.4.5.csv
# 85     2019-11-04T16.04.52.598                 1.4.5
# 86     2019-11-04T16.04.52.598                 1.4.5
#
# [87 rows x 4 columns]

# %%
# =====
# File readers
# =====
import re
import pandas as pd

def is_file(path, extension):
    """Check that the file at path ends with extension.
    
    Parameters
    =====
    path: str
    extension: str
        Regex
    
    Return
    =====
    ?: boolean
    """
    if re.search(extension, path).group():
        return True
    else:
        return False
    
def read_csv(path):
    """Read csv from path
    
    Parameters 
    =====
    path: str
        The path to the desired file to be read
    """
    return pd.read_csv(path)

# %%
# =====
# Plotting functions
# =====
import matplotlib.pyplot as plt

axes = ['x', 'y', 'z'] 
"""Available axes"""

axes_map = {
    'x': 3,
    'y': 4,
    'z': 5
}
"""Mapping for the axis to the column index in the dataframe"""

axes_color = {
    'x': 'r',
    'y': 'g',
    'z': 'b'
}
"""Mapping for the axis colors"""

time_axis_label = "Time (s)"
accel_axis_label = "Acceleration (g)"
time_index = 2

def plot_in_3d(df):
    """Plots the summation of x-, y- and z-axes in 3D space.
    Currently being reworked.
    """
    return None

def plot_time(df, var = 'x', ttl = ''):
    """Plots the desired parameter against time. 
    
    Parameters
    =====
    df: dataframe
    var: str
        The variable to be plotted as taken from the dictionary/
        Defaults to 'x'
    ttl: str
        Title of the graph
        
    Returns
    =====
    fig: figure
    """
    # Check that var is 'x', 'y', or 'z'
    # Defaults to 'x' if not used
    if var not in axes:
        var = 'x'
        
    # Get values
    time = df.iloc[:, 2]
    data = df.iloc[:, axes_map[var]]
    
    # Plot
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set(xlabel = time_axis_label, ylabel = var, title = ttl)
    ax.grid(b = True, which = 'both')
    ax.plot(time, data)
    
    return fig
    
def plot_time_3_axes(df, t = ''):
    """Plots all axes into a single plot in the time domain
    
    Parameters
    =====
    df: dataframe
    t: str
        Title
        
    Returns
    =====
    fig: figure
    """
    # Create figure
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set(
        xlabel = time_axis_label, 
        ylabel = accel_axis_label,
        title = t
    )
    ax.grid(b = True, which = 'both')
    
    # Plot all 3 axes
    for idx, axis in enumerate(axes_map):
        ax.plot(
            df.iloc[:, time_index],
            df.iloc[:, axes_map[axis]],
            axes_color[axis],
            label = axis
        )
        
    # Legend
    ax.legend()
    
    return fig
